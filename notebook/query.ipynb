# %%
from requests import get as GET
import pandas as pd

# %%
resp = GET("http://localhost:5001/meetup/mvg", auth=("admin", "hans"))
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'_id': '5ce8f6ef341dd6b291ea7511',
#  'code': 200,
#  'data': [{'color': '#dd3d4d',
#    'departure': '2019-05-25T10:08:00',
#    'destination': 'Feldmoching',
#    'distance': 209,
#    'label': 'U2',
#    'name': 'Königsplatz',
#    'product': 'UBAHN',
#    'station': '110',
#    'walk': '2019-05-25T10:04:00'},
#   {'color': '#468447',
#    'departure': '2019-05-25T10:09:00',
#    'destination': 'Olympia - Einkaufszentrum',
#    'distance': 255,
#    'label': 'U1',
#    'name': 'Stiglmaierplatz',
#    'product': 'UBAHN',
#    'station': '170',
#    'walk': '2019-05-25T10:04:00'},
#   {'color': '#0d5c70',
#    'departure': '2019-05-25T10:09:00',
#    'destination': 'CityRing via Pinakotheken - Giselastraße',
#    'distance': 209,
#    'label': '58',
#    'name': 'Königsplatz',
#    'product': 'BUS',
#    'station': '110',
#    'walk': '2019-05-25T10:05:00'},
#   {'color': '#ea4029',
#    'departure': '2019-05-25T10:10:00',
#    'destination': 'Moosach Bf.',
#    'distance': 255,
#    'label': '20',
#    'name': 'Stiglmaierplatz',
#    'product': 'TRAM',
#    'station': '170',
#    'walk': '2019-05-25T10:05:00'},
#   {'color': '#ea4029',
#    'departure': '2019-05-25T10:10:00',
#    'destination': 'Karlsplatz (Stachus)',
#    'distance': 255,
#    'label': '21',
#    'name': 'Stiglmaierplatz',
#    'product': 'TRAM',
#    'station': '170',
#    'walk': '2019-05-25T10:05:00'},
#   {'color': '#dd3d4d',
#    'departure': '2019-05-25T10:10:00',
#    'destination': 'Hauptbahnhof',
#    'distance': 209,
#    'label': 'U2',
#    'name': 'Königsplatz',
#    'product': 'UBAHN',
#    'station': '110',
#    'walk': '2019-05-25T10:06:00'},
#   {'color': '#ea4029',
#    'departure': '2019-05-25T10:11:00',
#    'destination': 'Karlsplatz (Stachus)',
#    'distance': 255,
#    'label': '21',
#    'name': 'Karlstraße',
#    'product': 'TRAM',
#    'station': '15',
#    'walk': '2019-05-25T10:06:00'},
#   {'color': '#ea4029',
#    'departure': '2019-05-25T10:12:00',
#    'destination': 'Westfriedhof',
#    'distance': 255,
#    'label': '21',
#    'name': 'Karlstraße',
#    'product': 'TRAM',
#    'station': '15',
#    'walk': '2019-05-25T10:07:00'},
#   {'color': '#ea4029',
#    'departure': '2019-05-25T10:13:00',
#    'destination': 'Karlsplatz (Stachus)',
#    'distance': 255,
#    'label': '20',
#    'name': 'Stiglmaierplatz',
#    'product': 'TRAM',
#    'station': '170',
#    'walk': '2019-05-25T10:08:00'},
#   {'color': '#468447',
#    'departure': '2019-05-25T10:13:00',
#    'destination': 'Hauptbahnhof',
#    'distance': 255,
#    'label': 'U1',
#    'name': 'Stiglmaierplatz',
#    'product': 'UBAHN',
#    'station': '170',
#    'walk': '2019-05-25T10:08:00'},
#   {'color': '#ea4029',
#    'departure': '2019-05-25T10:14:00',
#    'destination': 'Karlsplatz (Stachus)',
#    'distance': 255,
#    'label': '20',
#    'name': 'Karlstraße',
#    'product': 'TRAM',
#    'station': '15',
#    'walk': '2019-05-25T10:09:00'},
#   {'color': '#ea4029',
#    'departure': '2019-05-25T10:14:00',
#    'destination': 'Westfriedhof',
#    'distance': 255,
#    'label': '21',
#    'name': 'Stiglmaierplatz',
#    'product': 'TRAM',
#    'station': '170',
#    'walk': '2019-05-25T10:09:00'},
#   {'color': '#0d5c70',
#    'departure': '2019-05-25T10:15:00',
#    'destination': 'Ostbahnhof',
#    'distance': 209,
#    'label': '100',
#    'name': 'Königsplatz',
#    'product': 'BUS',
#    'station': '110',
#    'walk': '2019-05-25T10:11:00'},
#   {'color': '#0d5c70',
#    'departure': '2019-05-25T10:15:00',
#    'destination': 'CityRing via Hauptbahnhof - Silberhornstraße',
#    'distance': 209,
#    'label': '68',
#    'name': 'Königsplatz',
#    'product': 'BUS',
#    'station': '110',
#    'walk': '2019-05-25T10:11:00'},
#   {'color': '#ea4029',
#    'departure': '2019-05-25T10:16:00',
#    'destination': 'Moosach Bf.',
#    'distance': 255,
#    'label': '20',
#    'name': 'Karlstraße',
#    'product': 'TRAM',
#    'station': '15',
#    'walk': '2019-05-25T10:11:00'},
#   {'color': '#0d5c70',
#    'departure': '2019-05-25T10:18:00',
#    'destination': 'Hauptbahnhof Nord',
#    'distance': 209,
#    'label': '100',
#    'name': 'Königsplatz',
#    'product': 'BUS',
#    'station': '110',
#    'walk': '2019-05-25T10:14:00'}],
#  'message': 'OK',
#  'timestamp': '2019-05-25T08:04:00.107825'}

# %%
df = pd.DataFrame(resp.json()["data"])
df.head()
# Out:
#      color            departure                               destination  \
# 0  #dd3d4d  2019-05-25T10:08:00                               Feldmoching
# 1  #468447  2019-05-25T10:09:00                 Olympia - Einkaufszentrum
# 2  #0d5c70  2019-05-25T10:09:00  CityRing via Pinakotheken - Giselastraße
# 3  #ea4029  2019-05-25T10:10:00                               Moosach Bf.
# 4  #ea4029  2019-05-25T10:10:00                      Karlsplatz (Stachus)
#
#    distance label             name product station                 walk
# 0       209    U2      Königsplatz   UBAHN     110  2019-05-25T10:04:00
# 1       255    U1  Stiglmaierplatz   UBAHN     170  2019-05-25T10:04:00
# 2       209    58      Königsplatz     BUS     110  2019-05-25T10:05:00
# 3       255    20  Stiglmaierplatz    TRAM     170  2019-05-25T10:05:00
# 4       255    21  Stiglmaierplatz    TRAM     170  2019-05-25T10:05:00
